# %%
import os 
from pathlib import Path
import logging

# %%
# %pwd
# Out:
# 'f:\\ML_Ops_learning\\Kidney_Disease_Classification_MLflow\\notebooks'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'f:\\ML_Ops_learning\\Kidney_Disease_Classification_MLflow'

# %%
project_name="cnnclf"

list_of_files = [
    ".github/workflows/main.yaml",
    f"src/{project_name}/__init__.py",
    
    f"src/{project_name}/components/__init__.py",
    f"src/{project_name}/components/data_ingestion.py",
    f"src/{project_name}/components/prepare_base_model.py",
    f"src/{project_name}/components/model_training.py",
    f"src/{project_name}/components/model_evaluation_mlflow.py",
    
    f"src/{project_name}/config/__init__.py",
    
    f"src/{project_name}/constants/__init__.py",

    f"src/{project_name}/entity/__init__.py",

    f"src/{project_name}/pipeline/__init__.py",
    f"src/{project_name}/pipeline/stage_01_data_ingestion.py",
    f"src/{project_name}/pipeline/stage_02_prepare_base_model.py",
    f"src/{project_name}/pipeline/stage_03_model_training.py",
    f"src/{project_name}/pipeline/stage_04_model_evaluation_mlflow.py",
    
    f"src/{project_name}/utils/__init__.py",    
    "config/config.yaml",
    "params.yaml",
    "dvc.yaml",

    "app.py",
    "main.py",
    "requirements.txt",
    "setup.py",
    "templates/index.html"
]

# %%
for filepath in list_of_files:
    filepath = Path(filepath)
    filedir, filename = os.path.split(filepath)

    if filedir != "":
        os.makedirs(filedir, exist_ok=True)
        logging.info(f"Creating directory:{filedir} for the file {filename}")
    
    if (not os.path.exists(filepath)) or (os.path.getsize(filepath) == 0):
        with open(filepath,'w') as f:
            pass
            logging.info(f"Creating empty file: {filepath}")
    else:
        logging.info(f"{filename} is already exists")

# %% [markdown]
# ## requirement.txt

# %%
# %%writefile -a requirements.txt
# tensorflow
# pandas
# dvc
# mlflow
# notebook
# numpy
# matplotlib
# seaborn
# python-box
# pyYAML
# tqdm
# ensure
# joblib
# types-PyYAML
# scipy
# Flask
# Flask-Cors
# gdown
# -e .
# Out:
# Appending to requirements.txt

# %% [markdown]
# # setup.py

# %%
# %%writefile -a setup.py
import setuptools

with open("README.md", "r", encoding="utf-8") as f:
    long_description = f.read()


__version__ = "0.0.0"

GITHUB_REPO_NAME = "Kidney_Disease_Classification_MLflow"
GITHUB_AUTHOR_USER_NAME = "SunilKumar-ugra"
SRC_REPO = "cnnclf"
GITHUB_AUTHOR_EMAIL = "ugargolsunilkumar@gmail.com"



setuptools.setup(
    name=SRC_REPO,
    version=__version__,
    author=GITHUB_AUTHOR_USER_NAME,
    author_email=GITHUB_AUTHOR_EMAIL,
    description="Kidney stones prediction",
    long_description=long_description,
    long_description_content="text/markdown",
    url=f"https://github.com/{GITHUB_AUTHOR_USER_NAME}/{GITHUB_REPO_NAME}",
    project_urls={
        "Bug Tracker": f"https://github.com/{GITHUB_AUTHOR_USER_NAME}/{GITHUB_REPO_NAME}/issues",
    },
    package_dir={"": "src"},
    packages=setuptools.find_packages(where="src")
)
# Out:
# Appending to setup.py

# %%
# %pip install -r requirements.txt
# Out:
# Obtaining file:///F:/ML_Ops_learning/Kidney_Disease_Classification_MLflow (from -r requirements.txt (line 19))
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: tensorflow in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from -r requirements.txt (line 1)) (2.13.0)
# Requirement already satisfied: pandas in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from -r requirements.txt (line 2)) (2.0.3)
# Requirement already satisfied: dvc in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from -r requirements.txt (line 3)) (3.27.0)
# Requirement already satisfied: mlflow in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from -r requirements.txt (line 4)) (2.7.1)
# Requirement already satisfied: notebook in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from -r requirements.txt (line 5)) (7.0.6)
# Requirement already satisfied: numpy in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from -r requirements.txt (line 6)) (1.24.3)
# Requirement already satisfied: matplotlib in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from -r requirements.txt (line 7)) (3.7.3)
# Requirement already satisfied: seaborn in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from -r requirements.txt (line 8)) (0.13.0)
# Requirement already satisfied: python-box in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from -r requirements.txt (line 9)) (7.1.1)
# Requirement already satisfied: pyYAML in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from -r requirements.txt (line 10)) (6.0.1)
# Requirement already satisfied: tqdm in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from -r requirements.txt (line 11)) (4.66.1)
# Requirement already satisfied: ensure in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from -r requirements.txt (line 12)) (1.0.3)
# Requirement already satisfied: joblib in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from -r requirements.txt (line 13)) (1.3.2)
# Requirement already satisfied: types-PyYAML in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from -r requirements.txt (line 14)) (6.0.12.12)
# Requirement already satisfied: scipy in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from -r requirements.txt (line 15)) (1.10.1)
# Requirement already satisfied: Flask in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from -r requirements.txt (line 16)) (2.3.3)
# Requirement already satisfied: Flask-Cors in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from -r requirements.txt (line 17)) (4.0.0)
# Requirement already satisfied: gdown in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from -r requirements.txt (line 18)) (4.7.1)
# Requirement already satisfied: tensorflow-intel==2.13.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from tensorflow->-r requirements.txt (line 1)) (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 1)) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 1)) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 1)) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 1)) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 1)) (16.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 1)) (3.3.0)
# Requirement already satisfied: packaging in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 1)) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 1)) (4.24.4)
# Requirement already satisfied: setuptools in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 1)) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 1)) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 1)) (1.59.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 1)) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 1)) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 1)) (2.13.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 1)) (0.31.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2023.3)
# Requirement already satisfied: colorama>=0.3.9 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (0.4.6)
# Requirement already satisfied: configobj>=5.0.6 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (5.0.8)
# Requirement already satisfied: distro>=1.3 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (1.8.0)
# Requirement already satisfied: dpath<3,>=2.1.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (2.1.6)
# Requirement already satisfied: dvc-data<2.19.0,>=2.18.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (2.18.2)
# Requirement already satisfied: dvc-http>=2.29.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (2.30.2)
# Requirement already satisfied: dvc-render<1,>=0.3.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (0.6.0)
# Requirement already satisfied: dvc-studio-client<1,>=0.13.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (0.15.0)
# Requirement already satisfied: dvc-task<1,>=0.3.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (0.3.0)
# Requirement already satisfied: flatten-dict<1,>=0.4.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (0.4.2)
# Requirement already satisfied: flufl.lock<8,>=5 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (7.1.1)
# Requirement already satisfied: funcy>=1.14 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (2.0)
# Requirement already satisfied: grandalf<1,>=0.7 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (0.8)
# Requirement already satisfied: gto<2,>=1.4.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: hydra-core>=1.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (1.3.2)
# Requirement already satisfied: iterative-telemetry>=0.0.7 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (0.0.8)
# Requirement already satisfied: networkx>=2.5 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (3.1)
# Requirement already satisfied: pathspec>=0.10.3 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (0.11.2)
# Requirement already satisfied: platformdirs<4,>=3.1.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (3.11.0)
# Requirement already satisfied: psutil>=5.8 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (5.9.0)
# Requirement already satisfied: pydot>=1.2.4 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (1.4.2)
# Requirement already satisfied: pygtrie>=2.3.2 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (2.5.0)
# Requirement already satisfied: pyparsing>=2.4.7 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (3.1.1)
# Requirement already satisfied: requests>=2.22 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (2.31.0)
# Requirement already satisfied: rich>=12 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (13.6.0)
# Requirement already satisfied: ruamel.yaml>=0.17.11 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (0.18.2)
# Requirement already satisfied: scmrepo<2,>=1.2.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: shortuuid>=0.5 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (1.0.11)
# Requirement already satisfied: shtab<2,>=1.3.4 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (1.6.4)
# Requirement already satisfied: tabulate>=0.8.7 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (0.9.0)
# Requirement already satisfied: tomlkit>=0.11.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: voluptuous>=0.11.7 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (0.13.1)
# Requirement already satisfied: zc.lockfile>=1.2.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc->-r requirements.txt (line 3)) (3.0.post1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from mlflow->-r requirements.txt (line 4)) (8.1.7)
# Requirement already satisfied: cloudpickle<3 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from mlflow->-r requirements.txt (line 4)) (2.2.1)
# Requirement already satisfied: databricks-cli<1,>=0.8.7 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from mlflow->-r requirements.txt (line 4)) (0.18.0)
# Requirement already satisfied: entrypoints<1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from mlflow->-r requirements.txt (line 4)) (0.4)
# Requirement already satisfied: gitpython<4,>=2.1.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from mlflow->-r requirements.txt (line 4)) (3.1.40)
# Requirement already satisfied: importlib-metadata!=4.7.0,<7,>=3.7.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from mlflow->-r requirements.txt (line 4)) (6.8.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from mlflow->-r requirements.txt (line 4)) (0.4.4)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from mlflow->-r requirements.txt (line 4)) (1.12.1)
# Requirement already satisfied: docker<7,>=4.0.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from mlflow->-r requirements.txt (line 4)) (6.1.3)
# Requirement already satisfied: querystring-parser<2 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from mlflow->-r requirements.txt (line 4)) (1.2.4)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from mlflow->-r requirements.txt (line 4)) (2.0.22)
# Requirement already satisfied: scikit-learn<2 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from mlflow->-r requirements.txt (line 4)) (1.3.2)
# Requirement already satisfied: pyarrow<14,>=4.0.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from mlflow->-r requirements.txt (line 4)) (13.0.0)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from mlflow->-r requirements.txt (line 4)) (3.5)
# Requirement already satisfied: waitress<3 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from mlflow->-r requirements.txt (line 4)) (2.1.2)
# Requirement already satisfied: Jinja2<4,>=3.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from mlflow->-r requirements.txt (line 4)) (3.1.2)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from notebook->-r requirements.txt (line 5)) (2.9.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from notebook->-r requirements.txt (line 5)) (2.25.0)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from notebook->-r requirements.txt (line 5)) (4.0.7)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from notebook->-r requirements.txt (line 5)) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from notebook->-r requirements.txt (line 5)) (6.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from matplotlib->-r requirements.txt (line 7)) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from matplotlib->-r requirements.txt (line 7)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from matplotlib->-r requirements.txt (line 7)) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from matplotlib->-r requirements.txt (line 7)) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from matplotlib->-r requirements.txt (line 7)) (10.1.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from matplotlib->-r requirements.txt (line 7)) (6.1.0)
# Requirement already satisfied: Werkzeug>=2.3.7 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from Flask->-r requirements.txt (line 16)) (3.0.1)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from Flask->-r requirements.txt (line 16)) (2.1.2)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from Flask->-r requirements.txt (line 16)) (1.6.3)
# Requirement already satisfied: filelock in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from gdown->-r requirements.txt (line 18)) (3.12.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from gdown->-r requirements.txt (line 18)) (4.12.2)
# Requirement already satisfied: Mako in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from alembic!=1.10.0,<2->mlflow->-r requirements.txt (line 4)) (1.2.4)
# Requirement already satisfied: pyjwt>=1.7.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow->-r requirements.txt (line 4)) (2.8.0)
# Requirement already satisfied: oauthlib>=3.1.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow->-r requirements.txt (line 4)) (3.2.2)
# Requirement already satisfied: urllib3<3,>=1.26.7 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow->-r requirements.txt (line 4)) (2.0.7)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from docker<7,>=4.0.0->mlflow->-r requirements.txt (line 4)) (1.6.4)
# Requirement already satisfied: pywin32>=304 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from docker<7,>=4.0.0->mlflow->-r requirements.txt (line 4)) (305.1)
# Requirement already satisfied: dictdiffer>=0.8.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc-data<2.19.0,>=2.18.1->dvc->-r requirements.txt (line 3)) (0.9.0)
# Requirement already satisfied: dvc-objects<2,>=1.0.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc-data<2.19.0,>=2.18.1->dvc->-r requirements.txt (line 3)) (1.0.1)
# Requirement already satisfied: diskcache>=5.2.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc-data<2.19.0,>=2.18.1->dvc->-r requirements.txt (line 3)) (5.6.3)
# Requirement already satisfied: attrs>=21.3.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc-data<2.19.0,>=2.18.1->dvc->-r requirements.txt (line 3)) (23.1.0)
# Requirement already satisfied: sqltrie<1,>=0.8.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc-data<2.19.0,>=2.18.1->dvc->-r requirements.txt (line 3)) (0.8.0)
# Requirement already satisfied: fsspec[http] in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc-http>=2.29.0->dvc->-r requirements.txt (line 3)) (2023.10.0)
# Requirement already satisfied: aiohttp-retry>=2.5.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc-http>=2.29.0->dvc->-r requirements.txt (line 3)) (2.8.3)
# Requirement already satisfied: dulwich in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc-studio-client<1,>=0.13.0->dvc->-r requirements.txt (line 3)) (0.21.6)
# Requirement already satisfied: celery<6,>=5.3.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc-task<1,>=0.3.0->dvc->-r requirements.txt (line 3)) (5.3.4)
# Requirement already satisfied: kombu<6,>=5.3.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from dvc-task<1,>=0.3.0->dvc->-r requirements.txt (line 3)) (5.3.2)
# Requirement already satisfied: atpublic>=2.3 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from flufl.lock<8,>=5->dvc->-r requirements.txt (line 3)) (4.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from gitpython<4,>=2.1.0->mlflow->-r requirements.txt (line 4)) (4.0.11)
# Requirement already satisfied: typer>=0.4.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from gto<2,>=1.4.0->dvc->-r requirements.txt (line 3)) (0.9.0)
# Requirement already satisfied: pydantic!=2.0.0,<3,>=1.9.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from gto<2,>=1.4.0->dvc->-r requirements.txt (line 3)) (1.10.13)
# Requirement already satisfied: semver>=3.0.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from gto<2,>=1.4.0->dvc->-r requirements.txt (line 3)) (3.0.2)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from hydra-core>=1.1->dvc->-r requirements.txt (line 3)) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from hydra-core>=1.1->dvc->-r requirements.txt (line 3)) (4.9.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from importlib-metadata!=4.7.0,<7,>=3.7.0->mlflow->-r requirements.txt (line 4)) (3.17.0)
# Requirement already satisfied: appdirs in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from iterative-telemetry>=0.0.7->dvc->-r requirements.txt (line 3)) (1.4.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from Jinja2<4,>=3.0->mlflow->-r requirements.txt (line 4)) (2.1.3)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (4.0.0)
# Requirement already satisfied: argon2-cffi in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (23.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (8.5.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (5.4.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (0.8.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (7.9.2)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (5.9.2)
# Requirement already satisfied: overrides in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (7.4.0)
# Requirement already satisfied: prometheus-client in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (0.17.1)
# Requirement already satisfied: pywinpty in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (2.0.12)
# Requirement already satisfied: pyzmq>=24 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (25.1.1)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (0.17.1)
# Requirement already satisfied: traitlets>=5.6.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (5.12.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 5)) (2.0.4)
# Requirement already satisfied: ipykernel in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 5)) (6.26.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 5)) (2.2.0)
# Requirement already satisfied: tomli in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 5)) (2.0.1)
# Requirement already satisfied: babel>=2.10 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->-r requirements.txt (line 5)) (2.13.1)
# Requirement already satisfied: json5>=0.9.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->-r requirements.txt (line 5)) (0.9.14)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->-r requirements.txt (line 5)) (4.19.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from requests>=2.22->dvc->-r requirements.txt (line 3)) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from requests>=2.22->dvc->-r requirements.txt (line 3)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from requests>=2.22->dvc->-r requirements.txt (line 3)) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from rich>=12->dvc->-r requirements.txt (line 3)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from rich>=12->dvc->-r requirements.txt (line 3)) (2.16.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from ruamel.yaml>=0.17.11->dvc->-r requirements.txt (line 3)) (0.2.8)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from scikit-learn<2->mlflow->-r requirements.txt (line 4)) (3.2.0)
# Requirement already satisfied: pygit2>=1.13.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from scmrepo<2,>=1.2.1->dvc->-r requirements.txt (line 3)) (1.13.1)
# Requirement already satisfied: asyncssh<3,>=2.13.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from scmrepo<2,>=1.2.1->dvc->-r requirements.txt (line 3)) (2.14.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow->-r requirements.txt (line 4)) (3.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from beautifulsoup4->gdown->-r requirements.txt (line 18)) (2.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from requests[socks]->gdown->-r requirements.txt (line 18)) (1.7.1)
# Requirement already satisfied: aiohttp in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc->-r requirements.txt (line 3)) (3.8.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (1.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 1)) (0.41.2)
# Requirement already satisfied: cryptography>=39.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from asyncssh<3,>=2.13.1->scmrepo<2,>=1.2.1->dvc->-r requirements.txt (line 3)) (41.0.5)
# Requirement already satisfied: billiard<5.0,>=4.1.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from celery<6,>=5.3.0->dvc-task<1,>=0.3.0->dvc->-r requirements.txt (line 3)) (4.1.0)
# Requirement already satisfied: vine<6.0,>=5.0.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from celery<6,>=5.3.0->dvc-task<1,>=0.3.0->dvc->-r requirements.txt (line 3)) (5.0.0)
# Requirement already satisfied: click-didyoumean>=0.3.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from celery<6,>=5.3.0->dvc-task<1,>=0.3.0->dvc->-r requirements.txt (line 3)) (0.3.0)
# Requirement already satisfied: click-repl>=0.2.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from celery<6,>=5.3.0->dvc-task<1,>=0.3.0->dvc->-r requirements.txt (line 3)) (0.3.0)
# Requirement already satisfied: click-plugins>=1.1.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from celery<6,>=5.3.0->dvc-task<1,>=0.3.0->dvc->-r requirements.txt (line 3)) (1.1.1)
# Requirement already satisfied: backports.zoneinfo>=0.2.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from celery<6,>=5.3.0->dvc-task<1,>=0.3.0->dvc->-r requirements.txt (line 3)) (0.2.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow->-r requirements.txt (line 4)) (5.0.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->-r requirements.txt (line 5)) (2023.7.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->-r requirements.txt (line 5)) (1.3.10)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->-r requirements.txt (line 5)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->-r requirements.txt (line 5)) (0.10.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (2.0.7)
# Requirement already satisfied: rfc3339-validator in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (0.1.1)
# Requirement already satisfied: amqp<6.0.0,>=5.1.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from kombu<6,>=5.3.0->dvc-task<1,>=0.3.0->dvc->-r requirements.txt (line 3)) (5.1.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12->dvc->-r requirements.txt (line 3)) (0.1.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (6.1.0)
# Requirement already satisfied: defusedxml in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (0.2.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (1.2.1)
# Requirement already satisfied: fastjsonschema in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (2.18.1)
# Requirement already satisfied: cffi>=1.9.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from pygit2>=1.13.0->scmrepo<2,>=1.2.1->dvc->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: orjson in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from sqltrie<1,>=0.8.0->dvc-data<2.19.0,>=2.18.1->dvc->-r requirements.txt (line 3)) (3.9.10)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 1)) (2.23.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 1)) (0.7.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (21.2.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 5)) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 5)) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 5)) (8.12.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 5)) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 5)) (1.5.8)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc->-r requirements.txt (line 3)) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc->-r requirements.txt (line 3)) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc->-r requirements.txt (line 3)) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc->-r requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: webencodings in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from cffi>=1.9.1->pygit2>=1.13.0->scmrepo<2,>=1.2.1->dvc->-r requirements.txt (line 3)) (2.21)
# Requirement already satisfied: prompt-toolkit>=3.0.36 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from click-repl>=0.2.0->celery<6,>=5.3.0->dvc-task<1,>=0.3.0->dvc->-r requirements.txt (line 3)) (3.0.39)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 1)) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 1)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 1)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: backcall in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: decorator in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 5)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 5)) (0.19.1)
# Requirement already satisfied: pickleshare in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 5)) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 5)) (0.6.2)
# Requirement already satisfied: fqdn in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (2.4)
# Requirement already satisfied: uri-template in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (1.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 5)) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from prompt-toolkit>=3.0.36->click-repl>=0.2.0->celery<6,>=5.3.0->dvc-task<1,>=0.3.0->dvc->-r requirements.txt (line 3)) (0.2.8)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow->-r requirements.txt (line 1)) (0.5.0)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 5)) (2.4.0)
# Requirement already satisfied: pure-eval in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 5)) (0.2.2)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\win10\.conda\envs\cnncls\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 5)) (2.8.19.14)
# Installing collected packages: cnnclf
#   Running setup.py develop for cnnclf
# Successfully installed cnnclf-0.0.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Custom Logging

# %%
# %%writefile -a src/{project_name}/__init__.py
import logging
import os
from datetime import datetime
import sys

LOG_FILE=f"{datetime.now().strftime('%m_%d_%Y_%H_%M_%S')}.log"
logs_path=os.path.join(os.getcwd(),"logs",LOG_FILE)
os.makedirs(logs_path,exist_ok=True)

LOG_FILE_PATH=os.path.join(logs_path,LOG_FILE)

logging.basicConfig(
    format="[%(asctime)s] - %(name)s - %(levelname)s - %(module)s file - LineNum:%(lineno)d   - %(message)s",
    level=logging.INFO,
    handlers=[
        logging.FileHandler(LOG_FILE_PATH),
        logging.StreamHandler(sys.stdout)
    ]
)

logger=logging.getLogger("cnnclf")
# Out:
# Appending to src/cnnclf/__init__.py

# %% [markdown]
# ## Utility

# %%
# %%writefile -a src/{project_name}/utils/__init__.py
import os
from box.exceptions import BoxValueError
import yaml
from cnnClassifier import logger
import json
import joblib
from ensure import ensure_annotations
from box import ConfigBox
from pathlib import Path
from typing import Any
import base64



@ensure_annotations
def read_yaml(path_to_yaml: Path) -> ConfigBox:
    """reads yaml file and returns

    Args:
        path_to_yaml (str): path like input

    Raises:
        ValueError: if yaml file is empty
        e: empty file

    Returns:
        ConfigBox: ConfigBox type
    """
    try:
        with open(path_to_yaml) as yaml_file:
            content = yaml.safe_load(yaml_file)
            logger.info(f"yaml file: {path_to_yaml} loaded successfully")
            return ConfigBox(content)
    except BoxValueError:
        raise ValueError("yaml file is empty")
    except Exception as e:
        raise e
    


@ensure_annotations
def create_directories(path_to_directories: list, verbose=True):
    """create list of directories

    Args:
        path_to_directories (list): list of path of directories
        ignore_log (bool, optional): ignore if multiple dirs is to be created. Defaults to False.
    """
    for path in path_to_directories:
        os.makedirs(path, exist_ok=True)
        if verbose:
            logger.info(f"created directory at: {path}")


@ensure_annotations
def save_json(path: Path, data: dict):
    """save json data

    Args:
        path (Path): path to json file
        data (dict): data to be saved in json file
    """
    with open(path, "w") as f:
        json.dump(data, f, indent=4)

    logger.info(f"json file saved at: {path}")




@ensure_annotations
def load_json(path: Path) -> ConfigBox:
    """load json files data

    Args:
        path (Path): path to json file

    Returns:
        ConfigBox: data as class attributes instead of dict
    """
    with open(path) as f:
        content = json.load(f)

    logger.info(f"json file loaded succesfully from: {path}")
    return ConfigBox(content)


@ensure_annotations
def save_bin(data: Any, path: Path):
    """save binary file

    Args:
        data (Any): data to be saved as binary
        path (Path): path to binary file
    """
    joblib.dump(value=data, filename=path)
    logger.info(f"binary file saved at: {path}")


@ensure_annotations
def load_bin(path: Path) -> Any:
    """load binary data

    Args:
        path (Path): path to binary file

    Returns:
        Any: object stored in the file
    """
    data = joblib.load(path)
    logger.info(f"binary file loaded from: {path}")
    return data

@ensure_annotations
def get_size(path: Path) -> str:
    """get size in KB

    Args:
        path (Path): path of the file

    Returns:
        str: size in KB
    """
    size_in_kb = round(os.path.getsize(path)/1024)
    return f"~ {size_in_kb} KB"


def decodeImage(imgstring, fileName):
    imgdata = base64.b64decode(imgstring)
    with open(fileName, 'wb') as f:
        f.write(imgdata)
        f.close()


def encodeImageIntoBase64(croppedImagePath):
    with open(croppedImagePath, "rb") as f:
        return base64.b64encode(f.read())
# Out:
# Appending to src/cnnclf/utils/__init__.py

# %% [markdown]
# ## Params YAML

# %%
# %%writefile params.yaml
# AUGMENTATION: True
# IMAGE_SIZE: [224, 224, 3] # as per VGG 16 model
# BATCH_SIZE: 16
# INCLUDE_TOP: False
# EPOCHS: 1
# CLASSES: 2
# WEIGHTS: imagenet
# LEARNING_RATE: 0.01
# Out:
# Overwriting params.yaml

# %% [markdown]
# ## Intializing Path in Constant Constructor File

# %%
# %%writefile  src/{project_name}/constants/__init__.py
from pathlib import Path
CONFIG_FILE_PATH = Path("config/config.yaml")
PARAMS_FILE_PATH = Path("params.yaml")
# Out:
# Overwriting src/cnnclf/constants/__init__.py
